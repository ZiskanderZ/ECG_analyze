# %%
import pandas as pd
import numpy as np

import os
from pathlib import Path

import plotly
import plotly.graph_objs as go

from tsfresh import extract_features, select_features
from tsfresh.feature_extraction.settings import MinimalFCParameters, from_columns
from tsfresh.utilities.dataframe_functions import impute

from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score

from catboost import CatBoostClassifier

# %%
# define relative path
path = Path.cwd()

# %%
# read the data
path_to_data = os.path.join(path, 'data', 'physionet2017.csv')
df = pd.read_csv(path_to_data, index_col=[-2])
df.head()
# Out:
#                    0         1         2         3         4         5  \
# name
# A00/A00001  0.035032  0.037155  0.044586  0.063694  0.076433  0.085987
# A00/A00002 -0.035288 -0.032573 -0.030945 -0.029859 -0.031488 -0.034202
# A00/A00003 -0.303922 -0.261438 -0.222222 -0.192810 -0.176471 -0.163399
# A00/A00004  0.109467  0.117604  0.128698  0.142012  0.153107  0.161982
# A00/A00005 -0.019856 -0.017148 -0.014440 -0.011733 -0.009928 -0.008123
#
#                    6         7         8         9  ...      1991      1992  \
# name                                                ...
# A00/A00001  0.089172  0.083864  0.072187  0.061571  ...  0.020170  0.008493
# A00/A00002 -0.037459 -0.040717 -0.043974 -0.047231  ... -0.002714 -0.001629
# A00/A00003 -0.147059 -0.130719 -0.117647 -0.107843  ... -0.339869 -0.346405
# A00/A00004  0.170118  0.176036  0.181213  0.184911  ...  0.846154  0.780325
# A00/A00005 -0.006318 -0.004513 -0.003610 -0.001805  ... -0.347473 -0.306859
#
#                 1993      1994      1995      1996      1997      1998  \
# name
# A00/A00001  0.000000 -0.007431 -0.012739 -0.015924 -0.019108 -0.023355
# A00/A00002 -0.001086 -0.000543 -0.000543  0.000000  0.000000  0.000543
# A00/A00003 -0.339869 -0.323529 -0.297386 -0.264706 -0.209150 -0.117647
# A00/A00004  0.640533  0.467456  0.298077  0.165680  0.085799  0.012574
# A00/A00005 -0.260830 -0.214801 -0.168773 -0.124549 -0.083935 -0.051444
#
#                 1999  label
# name
# A00/A00001 -0.022293      0
# A00/A00002  0.001086      0
# A00/A00003 -0.065359      0
# A00/A00004  0.013314      1
# A00/A00005  0.000000      1
#
# [5 rows x 2001 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8528 entries, A00/A00001 to A08/A08528
# Columns: 2001 entries, 0 to label
# dtypes: float64(2000), int64(1)
# memory usage: 130.3+ MB

# %%
# labels variance
df['label'].value_counts()
# Out:
# 0    5076
# 2    2415
# 1     758
# 3     279
# Name: label, dtype: int64

# %%
# labels info
info_dict = {0: 'Normal', 1: 'AF', 2: 'Other', 3: 'Noise'}

# %%
# # data visualization
# def visual(row):
#     name = row.name.replace('/', '_')
#     row = row.values
#     fig = go.Figure()
#     fig.add_trace(go.Scatter(y=row[:-1]))
#     fig.update_layout(title={
#                             'text': info_dict[row[-1]],
#                             'font_size': 24,
#                             'y':0.9,
#                             'x':0.5})
#     fig.write_html(os.path.join('figures', f'{name}.html'))

# df.apply(visual, axis=1)

# %%
# labels visualization
for label in df['label'].unique():
    fig = go.Figure()
    fig.add_trace(go.Scatter(y=df[df['label'] == label].iloc[1, :-1]))
    fig.update_layout(title=info_dict[label])
    fig.show()

# %%
# check NaNs
df.isna().sum().sum()
# Out:
# 0

# %%
# select features and target
features_df = df.drop(columns={'label'})
label = df['label']
features_df.head()
# Out:
#                    0         1         2         3         4         5  \
# name
# A00/A00001  0.035032  0.037155  0.044586  0.063694  0.076433  0.085987
# A00/A00002 -0.035288 -0.032573 -0.030945 -0.029859 -0.031488 -0.034202
# A00/A00003 -0.303922 -0.261438 -0.222222 -0.192810 -0.176471 -0.163399
# A00/A00004  0.109467  0.117604  0.128698  0.142012  0.153107  0.161982
# A00/A00005 -0.019856 -0.017148 -0.014440 -0.011733 -0.009928 -0.008123
#
#                    6         7         8         9  ...      1990      1991  \
# name                                                ...
# A00/A00001  0.089172  0.083864  0.072187  0.061571  ...  0.038217  0.020170
# A00/A00002 -0.037459 -0.040717 -0.043974 -0.047231  ... -0.003800 -0.002714
# A00/A00003 -0.147059 -0.130719 -0.117647 -0.107843  ... -0.330065 -0.339869
# A00/A00004  0.170118  0.176036  0.181213  0.184911  ...  0.844675  0.846154
# A00/A00005 -0.006318 -0.004513 -0.003610 -0.001805  ... -0.381769 -0.347473
#
#                 1992      1993      1994      1995      1996      1997  \
# name
# A00/A00001  0.008493  0.000000 -0.007431 -0.012739 -0.015924 -0.019108
# A00/A00002 -0.001629 -0.001086 -0.000543 -0.000543  0.000000  0.000000
# A00/A00003 -0.346405 -0.339869 -0.323529 -0.297386 -0.264706 -0.209150
# A00/A00004  0.780325  0.640533  0.467456  0.298077  0.165680  0.085799
# A00/A00005 -0.306859 -0.260830 -0.214801 -0.168773 -0.124549 -0.083935
#
#                 1998      1999
# name
# A00/A00001 -0.023355 -0.022293
# A00/A00002  0.000543  0.001086
# A00/A00003 -0.117647 -0.065359
# A00/A00004  0.012574  0.013314
# A00/A00005 -0.051444  0.000000
#
# [5 rows x 2000 columns]

# %%
# split to the valid data
X, X_val, y, y_val = train_test_split(features_df, label, test_size=0.1, shuffle=True)

# %%
X_val.to_csv(os.path.join('validation', 'data.csv'))
y_val.to_csv(os.path.join('validation', 'target.csv'))

# %% [markdown]
# ## Applying tsfresh library to analyze data

# %%
# vectorized data
data_long = pd.DataFrame({0: X.values.flatten(),
                          1: X.index.repeat(features_df.shape[1])})
data_long.head()
# Out:
#           0           1
# 0 -0.041031  A05/A05368
# 1 -0.041031  A05/A05368
# 2 -0.041985  A05/A05368
# 3 -0.044847  A05/A05368
# 4 -0.047710  A05/A05368

# %%
# calculate features
extracted_features = extract_features(data_long, column_id=1, impute_function=impute, default_fc_parameters=MinimalFCParameters()).sort_index()
extracted_features.head()
# Out:
# Feature Extraction: 100%|██████████| 40/40 [00:03<00:00, 11.07it/s]
#             0__sum_values  0__median   0__mean  0__length  \
# A00/A00001      54.674098  -0.001062  0.027337     2000.0
# A00/A00002      17.956569  -0.005429  0.008978     2000.0
# A00/A00003     -37.196078   0.086601 -0.018598     2000.0
# A00/A00004      55.476331  -0.018121  0.027738     2000.0
# A00/A00005      42.030686  -0.018051  0.021015     2000.0
#
#             0__standard_deviation  0__variance  0__root_mean_square  \
# A00/A00001               0.161908     0.026214             0.164199
# A00/A00002               0.097265     0.009460             0.097678
# A00/A00003               0.433558     0.187972             0.433957
# A00/A00004               0.156104     0.024369             0.158550
# A00/A00005               0.168624     0.028434             0.169929
#
#             0__maximum  0__absolute_maximum  0__minimum
# A00/A00001         1.0             1.000000   -0.168790
# A00/A00002         1.0             1.000000   -0.282302
# A00/A00003         1.0             2.578431   -2.578431
# A00/A00004         1.0             1.000000   -0.103550
# A00/A00005         1.0             1.000000   -0.443141

# %%
# split to the test data
y = y.sort_index()
X_train, X_test, y_train, y_test = train_test_split(extracted_features, y, test_size=0.3, shuffle=True)

# %%
# select importance features
X_train = select_features(X_train, y_train)
X_train.head()
# Out:
#             0__minimum  0__median  0__root_mean_square  0__absolute_maximum  \
# A01/A01026   -0.311745  -0.020307             0.158488             1.000000
# A03/A03211   -0.608345  -0.045760             0.226977             1.000000
# A00/A00972   -0.385740  -0.032907             0.176849             1.000000
# A01/A01876   -0.757962  -0.133758             0.356975             1.000000
# A07/A07691   -1.036446  -0.043280             0.242947             1.036446
#
#             0__standard_deviation  0__variance  0__sum_values   0__mean
# A01/A01026               0.157570     0.024828      34.061471  0.017031
# A03/A03211               0.226897     0.051482      12.079408  0.006040
# A00/A00972               0.176380     0.031110      25.744973  0.012872
# A01/A01876               0.356555     0.127131     -34.633758 -0.017317
# A07/A07691               0.242360     0.058738     -33.758542 -0.016879

# %%
from_columns(X_test)
# Out:
# {'0': {'minimum': None,
#   'median': None,
#   'root_mean_square': None,
#   'absolute_maximum': None,
#   'standard_deviation': None,
#   'variance': None,
#   'sum_values': None,
#   'mean': None}}

# %%
X_train.columns
# Out:
# Index(['0__minimum', '0__median', '0__root_mean_square', '0__absolute_maximum',
#        '0__standard_deviation', '0__variance', '0__sum_values', '0__mean'],
#       dtype='object')

# %%
# select features from test data
X_test = X_test[X_train.columns]
X_test
# Out:
#             0__minimum  0__median  0__root_mean_square  0__absolute_maximum  \
# A01/A01808   -0.662712  -0.017373             0.224498             1.000000
# A06/A06944   -1.007764  -0.034161             0.284732             1.007764
# A07/A07845   -2.084249   0.007326             0.357960             2.084249
# A01/A01227   -0.326121  -0.041731             0.151107             1.000000
# A07/A07792   -0.258838  -0.010101             0.137078             1.000000
# ...                ...        ...                  ...                  ...
# A03/A03246   -0.719101  -0.031835             0.198472             1.000000
# A05/A05690   -7.435897   0.136752             1.090808             7.435897
# A00/A00436   -0.298182  -0.007273             0.134967             1.000000
# A06/A06493   -0.264875  -0.018234             0.173913             1.000000
# A03/A03395   -0.576613  -0.010081             0.173720             1.000000
#
#             0__standard_deviation  0__variance  0__sum_values   0__mean
# A01/A01808               0.223109     0.049777      49.878814  0.024939
# A06/A06944               0.280524     0.078694     -97.532609 -0.048766
# A07/A07845               0.356789     0.127298     -57.882784 -0.028941
# A01/A01227               0.150902     0.022771      15.748068  0.007874
# A07/A07792               0.136395     0.018604      27.335859  0.013668
# ...                           ...          ...            ...       ...
# A03/A03246               0.198274     0.039313      17.737828  0.008869
# A05/A05690               1.079313     1.164916    -315.880342 -0.157940
# A00/A00436               0.134343     0.018048      25.916364  0.012958
# A06/A06493               0.172790     0.029856      39.474088  0.019737
# A03/A03395               0.173357     0.030053      22.443548  0.011222
#
# [2303 rows x 8 columns]

# %% [markdown]
# ### CatBoost

# %%
# init, train and predict model
model = CatBoostClassifier(iterations=100, verbose=False)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.30696457254222004

# %%
model.save_model('CB_0.3.onnx')
